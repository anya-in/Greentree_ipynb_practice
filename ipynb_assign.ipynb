# %% [markdown]
# # 📊 Data Visualization Example
#
# This notebook demonstrates how to read a CSV file using `pandas` and plot a simple graph using `matplotlib`.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("predicted_delays.csv")
df.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0   NaN    NaN           5          4   1455.0        1455      NaN
# 1   NaN    NaN           5          4   1910.0        1900      NaN
# 2   NaN    NaN           7          4    700.0         700      NaN
# 3   NaN    NaN          12          4      NaN         645      NaN
# 4   NaN    NaN          12          4    812.0         815      NaN
#
#    CRSArrTime UniqueCarrier  FlightNum  ... TaxiOut  Cancelled  \
# 0        1650            WN        227  ...     8.0          0
# 1        2154            UA       1746  ...    11.0          0
# 2         755            AS         60  ...     NaN          0
# 3         937            UA        482  ...    10.0          1
# 4        1000            US        103  ...    13.0          0
#
#    CancellationCode  Diverted  CarrierDelay  WeatherDelay NASDelay  \
# 0               NaN         0           0.0           0.0      0.0
# ...

# %%
plt.figure(figsize=(8, 5))
plt.plot(df["FlightNum"], df["Cancelled"], marker='o', linestyle='-', color='skyblue')
plt.title("Most commonly cancelled Flights")
plt.xlabel("FlightNum")
plt.ylabel("Cancelled")
plt.grid(True)
plt.tight_layout()
plt.show()
